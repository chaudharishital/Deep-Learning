# %% [markdown]
# <a href="https://colab.research.google.com/github/chaudharishital/Deep-Learning/blob/main/different_ways_to_read_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ways to read images

# %%
import tensorflow as tf

# %%
import numpy as np

# %%
from IPython.display import Image

# %%
Image(filename="/20200315_134441.jpg",width=200,height=300)

# %%
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(filename,target_size=(300,300))

# %%
filename="/20200315_134441.jpg"

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
import cv2

# %%
imgg=cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg,cv2.COLOR_BGR2RGB))

# %%
from PIL import Image

# %%
im=Image.open(filename)

# %%
plt.imshow(im)

# %%
#lets load deep learning model

# %%
mobile=tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17235968/17225924 [==============================] - 0s 0us/step

# %%
#Creating a model
#Training a model
#test or validate
#predict

# %%
#preprocessing of image

# %%
img=image.load_img(filename,target_size=(300,300))

# %%
plt.imshow(img)

# %%
# Out:
# (300, 300, 3)

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
